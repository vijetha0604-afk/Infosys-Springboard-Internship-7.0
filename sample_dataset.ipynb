# %% [markdown]
# <a href="https://colab.research.google.com/github/vijetha0604-afk/Infosys-Springboard-Internship-7.0/blob/main/sample_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-af6af929-10a2-48a4-a44d-b739fafb64ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af6af929-10a2-48a4-a44d-b739fafb64ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel("skincare_dataset.xlsx")

# %%
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006          55.0                    802.0
# 1     skincare  SKU1  14.843523          95.0                    736.0
# 2     haircare  SKU2  11.319683          34.0                      8.0
# 3     skincare  SKU3  61.163343           NaN                     83.0
# 4     skincare  SKU4   4.805496          26.0                    871.0
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary          58.0         7.0
# 1        7460.900065                Female          53.0        30.0
# 2        9577.749626               Unknown           1.0        10.0
# 3        7766.836426            Non-binary          23.0        13.0
# 4        2686.505152            Non-binary           5.0         3.0
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df.tail()
# Out:
#      Product type    SKU      Price  Availability  Number of products sold  \
# 1535     haircare  SKU18  40.338128     22.128674               591.668206
# 1536     skincare  SKU90  15.184830     53.485834               333.813638
# 1537    cosmetics  SKU33  61.637522     62.910887               612.545864
# 1538    cosmetics  SKU94   2.881992           NaN               952.077131
# 1539     skincare  SKU15  37.263058     97.614744                      NaN
#
#       Revenue generated Customer demographics  Stock levels  Lead times  \
# 1535        9757.754964               Unknown     10.232899    9.575244
# 1536        9600.458348            Non-binary     65.532465   17.384109
# 1537        4941.742606            Non-binary      4.016312   17.565338
# 1538        7742.511492               Unknown     83.381056   26.585214
# 1539        6149.053643            Non-binary           NaN    8.241768
#
#       Order quantities  ...   Location  Lead time  Production volumes  \
# ...

# %%
df.shape
# Out:
# (1540, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1540 entries, 0 to 1539
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             1465 non-null   object
#  1   SKU                      1449 non-null   object
#  2   Price                    1444 non-null   float64
#  3   Availability             1446 non-null   float64
#  4   Number of products sold  1461 non-null   float64
#  5   Revenue generated        1446 non-null   float64
#  6   Customer demographics    1465 non-null   object
#  7   Stock levels             1466 non-null   float64
#  8   Lead times               1473 non-null   float64
#  9   Order quantities         1456 non-null   float64
#  10  Shipping times           1462 non-null   float64
#  11  Shipping carriers        1465 non-null   object
#  12  Shipping costs           1474 non-null   float64
#  13  Supplier name            1453 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Product type               75
# SKU                        91
# Price                      96
# Availability               94
# Number of products sold    79
# Revenue generated          94
# Customer demographics      75
# Stock levels               74
# Lead times                 67
# Order quantities           84
# Shipping times             78
# Shipping carriers          75
# Shipping costs             66
# Supplier name              87
# Location                   73
# Lead time                  81
# Production volumes         84
# Manufacturing lead time    76
# Manufacturing costs        76
# Inspection results         80
# Defect rates               83
# Transportation modes       80
# Routes                     81
# Costs                      74
# dtype: int64

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].mean())

# %%
df.isnull().sum()
# Out:
# Product type               75
# SKU                        91
# Price                       0
# Availability                0
# Number of products sold     0
# Revenue generated           0
# Customer demographics      75
# Stock levels                0
# Lead times                  0
# Order quantities            0
# Shipping times              0
# Shipping carriers          75
# Shipping costs              0
# Supplier name              87
# Location                   73
# Lead time                   0
# Production volumes          0
# Manufacturing lead time     0
# Manufacturing costs         0
# Inspection results         80
# Defect rates                0
# Transportation modes       80
# Routes                     81
# Costs                       0
# dtype: int64

# %%
object_columns = df.select_dtypes(include=['object']).columns

for col in object_columns:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# Product type               0
# SKU                        0
# Price                      0
# Availability               0
# Number of products sold    0
# Revenue generated          0
# Customer demographics      0
# Stock levels               0
# Lead times                 0
# Order quantities           0
# Shipping times             0
# Shipping carriers          0
# Shipping costs             0
# Supplier name              0
# Location                   0
# Lead time                  0
# Production volumes         0
# Manufacturing lead time    0
# Manufacturing costs        0
# Inspection results         0
# Defect rates               0
# Transportation modes       0
# Routes                     0
# Costs                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(5)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
text_columns = df.select_dtypes(include='object').columns

for col in text_columns:
    df[col] = df[col].str.strip()

# %%
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006     55.000000                    802.0
# 1     skincare  SKU1  14.843523     95.000000                    736.0
# 2     haircare  SKU2  11.319683     34.000000                      8.0
# 3     skincare  SKU3  61.163343     46.934421                     83.0
# 4     skincare  SKU4   4.805496     26.000000                    871.0
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary          58.0         7.0
# 1        7460.900065                Female          53.0        30.0
# 2        9577.749626               Unknown           1.0        10.0
# 3        7766.836426            Non-binary          23.0        13.0
# 4        2686.505152            Non-binary           5.0         3.0
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
text_columns = df.select_dtypes(include='object').columns

for col in text_columns:
    df[col] = df[col].str.title()

# %%
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     Haircare  Sku0  69.808006     55.000000                    802.0
# 1     Skincare  Sku1  14.843523     95.000000                    736.0
# 2     Haircare  Sku2  11.319683     34.000000                      8.0
# 3     Skincare  Sku3  61.163343     46.934421                     83.0
# 4     Skincare  Sku4   4.805496     26.000000                    871.0
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-Binary          58.0         7.0
# 1        7460.900065                Female          53.0        30.0
# 2        9577.749626               Unknown           1.0        10.0
# 3        7766.836426            Non-Binary          23.0        13.0
# 4        2686.505152            Non-Binary           5.0         3.0
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df.columns = df.columns.str.strip().str.replace(" ", "_")

# %%
df.columns
# Out:
# Index(['Product_type', 'SKU', 'Price', 'Availability',
#        'Number_of_products_sold', 'Revenue_generated', 'Customer_demographics',
#        'Stock_levels', 'Lead_times', 'Order_quantities', 'Shipping_times',
#        'Shipping_carriers', 'Shipping_costs', 'Supplier_name', 'Location',
#        'Lead_time', 'Production_volumes', 'Manufacturing_lead_time',
#        'Manufacturing_costs', 'Inspection_results', 'Defect_rates',
#        'Transportation_modes', 'Routes', 'Costs'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Product_type                object
# SKU                         object
# Price                      float64
# Availability               float64
# Number_of_products_sold    float64
# Revenue_generated          float64
# Customer_demographics       object
# Stock_levels               float64
# Lead_times                 float64
# Order_quantities           float64
# Shipping_times             float64
# Shipping_carriers           object
# Shipping_costs             float64
# Supplier_name               object
# Location                    object
# Lead_time                  float64
# Production_volumes         float64
# Manufacturing_lead_time    float64
# Manufacturing_costs        float64
# Inspection_results          object
# Defect_rates               float64
# Transportation_modes        object
# Routes                      object
# Costs                      float64
# dtype: object

# %%
df.describe()
# Out:
#              Price  Availability  Number_of_products_sold  Revenue_generated  \
# count  1535.000000   1535.000000              1535.000000        1535.000000
# mean     48.262274     46.969243               462.722081        5761.291470
# std      29.646777     29.594231               289.925358        2660.180713
# min       1.555101      0.887142                 7.496523         901.814698
# 25%      20.646965     21.661520               208.981863        2868.200650
# 50%      48.220725     46.934421               441.662364        5764.024759
# 75%      73.232560     71.398458               677.390910        8144.821296
# max     108.444371    115.812891              1083.078792       10866.650881
#
#        Stock_levels   Lead_times  Order_quantities  Shipping_times  \
# count   1535.000000  1535.000000       1535.000000     1535.000000
# mean      49.262441    15.809125         48.737113        5.735672
# std       30.591897     8.741266         26.122741        2.665449
# ...

# %%
df.to_excel("Cleaned_Skincare_Dataset.xlsx", index=False)

# %%
df.isnull().sum()
# Out:
# Product_type               0
# SKU                        0
# Price                      0
# Availability               0
# Number_of_products_sold    0
# Revenue_generated          0
# Customer_demographics      0
# Stock_levels               0
# Lead_times                 0
# Order_quantities           0
# Shipping_times             0
# Shipping_carriers          0
# Shipping_costs             0
# Supplier_name              0
# Location                   0
# Lead_time                  0
# Production_volumes         0
# Manufacturing_lead_time    0
# Manufacturing_costs        0
# Inspection_results         0
# Defect_rates               0
# Transportation_modes       0
# Routes                     0
# Costs                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (1535, 24)

# %%
df.to_excel("Product_Tracking_Dataset.xlsx", index=False)

# %%
from google.colab import files

files.download("Product_Tracking_Dataset.xlsx")
